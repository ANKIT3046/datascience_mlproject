# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKIT3046/datascience_mlproject/blob/computer-vision/computervission1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# reading images
image1=cv2.imread('images1.jpg')
image2=cv2.imread('images2.jpg')
image3=cv2.imread('dog4.jpg')

# %%
image1.shape
# Out:
# (225, 225, 3)

# %%
# resizing image2 to become equal to image1

image2=cv2.resize(image2,(225,225))

# %%
image1.shape
# Out:
# (225, 225, 3)

# %%
image2.shape
# Out:
# (225, 225, 3)

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2953DFE240>

# %%
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2953DFE048>

# %%
# now croppling image1 and image2
crop_img1=image1[0:,0:210]
crop_img2=image2[0:,50:225]

# %%
cv2_imshow(crop_img1)
cv2_imshow(crop_img2)
# Out:
# <PIL.Image.Image image mode=RGB size=210x225 at 0x7F2953DFED68>
# <PIL.Image.Image image mode=RGB size=175x225 at 0x7F2953DFEEF0>

# %%
import numpy as np
image=np.concatenate((crop_img1,crop_img2),axis=1)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=385x225 at 0x7F2953E0D2E8>

# %%
image.shape
# Out:
# (225, 385, 3)

# %%
image3.shape
# Out:
# (168, 300, 3)

# %%
image3.shape
cv2_imshow(image3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F2953E0D400>

# %%
image[75:100,165:205]=image3[5:30,165:205]

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=385x225 at 0x7F2953E0D630>
