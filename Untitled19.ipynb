# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKIT3046/datascience_mlproject/blob/python/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/Death'

# %%
# we are sending the request to the url and reciving the response
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Death - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Death","wgTitle":"Death","wgCurRevisionId":903101975,"wgRevisionId":903101975,"wgArticleId":8221,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles needing page number citations from January 2014","Wikipedia articles needing clarification from January 2014","Wikipedia indefinitely semi-protected pages","Use dmy dates from September 2016","Use American English from March 2013","All Wikipedia articles written in American English","Articles containing Latin-language text","All pages needing factual verification","Wikipedia articles needing factual veri
# ...

# %%
soup=BeautifulSoup(response.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Death - Wikipedia</title>
# ...

# %%
for alink in soup.find_all('a'):
  print(alink.get('href'))
# Out:
# None
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Dyeing
# /wiki/Dead_(disambiguation)
# /wiki/Death_(disambiguation)
# /wiki/File:Vanitas_Still_Life_by_Giovanni_Francesco_Barbieri.jpg
# /wiki/File:Vanitas_Still_Life_by_Giovanni_Francesco_Barbieri.jpg
# /wiki/Skull
# /wiki/File:CathedralOfTrier_Skeleton.JPG
# /wiki/File:CathedralOfTrier_Skeleton.JPG
# /wiki/Death_(personification)
# /wiki/Human_skeleton
# /wiki/Shroud
# /wiki/Scythe
# /wiki/Cathedral_of_Trier
# /wiki/Trier
# /wiki/Germany
# /wiki/File:Kuoleman_Puutarha_by_Hugo_Simberg.jpg
# /wiki/File:Kuoleman_Puutarha_by_Hugo_Simberg.jpg
# /wiki/Hugo_Simberg
# /wiki/Biological_process
# /wiki/Organism
# #cite_note-1
# /wiki/List_of_causes_of_death_by_rate
# /wiki/Senescence
# /wiki/Predation
# /wiki/Malnutrition
# /wiki/Disease
# /wiki/Suicide
# /wiki/Homicide
# /wiki/Starvation
# /wiki/Dehydration
# /wiki/Accident
# /wiki/Major_trauma
# /wiki/Trauma_(medicine)
# #cite_note-2
# /wiki/Decomposition
# ...

# %%
for ptag in soup.find_all('p'):
  #print(ptag.text)
  for btag in ptag.find_all('b'):
    print(btag.text)
# Out:
# Death
# Bibliography

# %%
import pandas as pd

# %%
list=[1,2,3,4]
list1=[3,4,5,6]
df=pd.DataFrame([list,list1],columns=['age','value','name','marks'])

# %%
df
# Out:
#    age  value  name  marks
# 0    1      2     3      4
# 1    3      4     5      6

# %%
list1=['ankit',20,59]
list2=['sdfgh',4,334]
df=pd.DataFrame([list1,list2],columns=['name','age','marks'])
df
# Out:
#     name  age  marks
# 0  ankit   20     59
# 1  sdfgh    4    334
