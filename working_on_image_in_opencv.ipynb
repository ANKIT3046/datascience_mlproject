# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKIT3046/datascience_mlproject/blob/computer-vision/working_on_image_in_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image1=cv2.imread('cou3.jpg')
image2=cv2.imread('cou4.jpg')

# %%
image1.shape
# Out:
# (168, 300, 3)

# %%
image2=cv2.resize(image2,(300,168))

# %%
image2.shape
# Out:
# (168, 300, 3)

# %%
image=image1-image2

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FABA92214E0>

# %%
new1=image2-image1

# %%
cv2_imshow(new1)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FABA91A4F60>

# %%
new2=image1+image2

# %%
cv2_imshow(new2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FABA91BE2B0>
