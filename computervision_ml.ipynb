# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKIT3046/datascience_mlproject/blob/computer-vision/computervision_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread('ankit.jpg')
img
# Out:
# array([[[ 88, 122, 146],
#         [ 86, 120, 144],
#         [ 78, 109, 134],
#         ...,
#         [231, 232, 206],
#         [232, 235, 209],
#         [230, 234, 205]],
#
#        [[ 63,  99, 117],
#         [ 63,  97, 113],
#         [ 67,  98, 113],
#         ...,
#         [224, 224, 200],
#         [228, 229, 203],
#         [226, 230, 201]],
#
#        [[ 84, 122, 127],
#         [ 85, 120, 123],
#         [109, 134, 130],
#         ...,
#         [222, 222, 198],
#         [225, 225, 201],
#         [225, 226, 200]],
#
#        ...,
#
#        [[254, 255, 245],
#         [254, 255, 245],
#         [254, 255, 245],
#         ...,
#         [ 74,  63,  89],
#         [133, 116, 160],
#         [162, 143, 198]],
#
#        [[254, 255, 245],
#         [254, 255, 245],
#         [254, 255, 245],
#         ...,
#         [ 48,  40,  71],
#         [ 87,  79, 116],
#         [158, 150, 191]],
#
#        [[254, 255, 245],
#         [254, 255, 245],
#         [254, 255, 245],
# ...

# %%
img.shape
# Out:
# (96, 96, 3)

# %%
# to display img
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7F8C81A46A90>

# %%
img=cv2.imread('ankit.jpg',1) # 1 for image same as it is in term of colour channel

# %%
img1=cv2.imread('ankit.jpg',0) # 0 for making image gray scale image
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=96x96 at 0x7F8C81A46828>

# %%
img2=cv2.imread('ankit.jpg',-1) # -1 to make image transprent
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7F8C820E0A90>

# %%
cv2_imshow(img[30:70,20:60])
# Out:
# <PIL.Image.Image image mode=RGB size=40x40 at 0x7F8C81A46BA8>

# %%
# image operation 
#->image compress
#->image decompress
#->zoom perticuler area
#->reverse

# %%
x,y,z=cv2.split(img)

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=L size=96x96 at 0x7F8C81A46080>

# %%
cv2_imshow(y)
# Out:
# <PIL.Image.Image image mode=L size=96x96 at 0x7F8C81A46128>

# %%
s=cv2.line(img,(0,0),(20,40),(0,0,60),3)
cv2_imshow(s)
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7F8C81A46E48>

# %%
q=cv2.rectangle(img1,(40,40),(70,70),(255,0,0),3)
cv2_imshow(q)
# Out:
# <PIL.Image.Image image mode=L size=96x96 at 0x7F8C81A46F60>
